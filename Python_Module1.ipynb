# %% [markdown]
# <a href="https://colab.research.google.com/github/RohithAyitha/SouthWest-Baptist-University-CIS5383/blob/main/Python_Module1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rohith Ayitha
# Python_module1.py
"""Comparing integers using if statements and comparison operators."""

print('Enter two integers, and I will tell you',
      'the relationships they satisfy.')

# Read the first integer
number1 = int(input('Enter first integer: '))

# Read the second integer
number2 = int(input('Enter second integer: '))

# Equality / inequality
if number1 == number2:
    print(number1, 'is equal to', number2)
else:
    print(number1, 'is not equal to', number2)

# Less than / greater than
if number1 < number2:
    print(number1, 'is less than', number2)
elif number1 > number2:
    print(number1, 'is greater than', number2)

# Less than or equal / greater than or equal
if number1 <= number2:
    print(number1, 'is less than or equal to', number2)
if number1 >= number2:
    print(number1, 'is greater than or equal to', number2)
# Out:
# Enter two integers, and I will tell you the relationships they satisfy.
# Enter first integer: 7
# Enter second integer: 42
# 7 is not equal to 42
# 7 is less than 42
# 7 is less than or equal to 42
